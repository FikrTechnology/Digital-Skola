# %% [markdown]
# <h2>Soal 1: Helper Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Misalkan kamu ingin mengetahui tentang kegunaan fungsi 'len' di Python, maka fungsi apa yang bisa kamu gunakan untuk menolong kamu?

# %%
# lengkapi code ini
'''kita dapat menggunakan fungsi print pada Python itu sendiri agar bisa menampilkan fungsi kegunaan dari len()'''
a = [1,4,23,5,2,6]

print(len(a))

'''jawaban yang keluar adalah 6, yang dimana hasil dari panjang list tersebut yang terpisahkan dengan koma'''
# Out:
# 6

# %% [markdown]
# <h2>Soal 2: Built-in Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Apa itu built-in Function?
#
# Sebutkan 3 built-in Function di pyhon!
#
# Berikan contoh masing2 1 cara penggunaan built-in function yang kamu sebutkan sebelumnya

# %% [markdown]
# #isi jawaban text disini
#
#  - Fungsi built-in Function pada python adalah sebuah syntax bawaan dari pertama kali kita mendownload Python itu sendiri.

# %%
#Example of built-in function 
'''3 Built in Function pada Python'''

str()
len()
int()
float()
print()

# %%
#Example of built-in function 
a = 12353
b = 12.42
c = [1, 4, 2, 6, 32]

# %%
#Example of built-in function 
print(str(a))
print(len(c))
print(float(a))
print(int(b))
# Out:
# 12353
# 5
# 12353.0
# 12

# %% [markdown]
# <h2>Soal 3: Method dan Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# - Apa perbedaan method dan function?

# %% [markdown]
# #isi jawaban text disini
#
# - Method adalah sebuah fungsi di dalam class seperti .append(), .sum()
#
# - Function adalah fungsi di luar class seperti def name_function()

# %% [markdown]
# <h2>Soal 4: Menggunakan Method String</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
kalimat = "Corona cepat selesai"

# gunakan method untuk mengubah nilai kalimat menjadi uppercase semua kemudian tampilkan hasilnya
print(kalimat.upper())

# gunakan method untuk menghitung berapa huruf e di dalam kalimat
print(kalimat.count('e'))
# Out:
# CORONA CEPAT SELESAI
# 3

# %% [markdown]
# Expected Output:
#
# CORONA CEPAT SELESAI
#
# 3

# %% [markdown]
# <h2>Soal 5: Membuat Simple Function</h2>
#
# Buatlah suatu fungsi yang menerima satu input argumen berbentuk list dan mempunyai elemen bertipe numeric semua, dimana fungsi tersebut berguna untuk menghitung rata2 dari kumpulan elemen list tersebut. namai fungsi tersebut 'mean_list'

# %%
obj_list = [11.25, 18.0, 20.0, 10.75, 9.50]

#yourcode
def mean_list(inp_list):
  rata_rata = sum(inp_list) / len(inp_list)
  return rata_rata

mean_list(obj_list)
# Out:
# 13.9

# %% [markdown]
# Expected Output:
#
# 13.9

# %% [markdown]
# <h2>Soal 6: Membuat Function dengan Multiple arguments</h2>
#
# Buatlah suatu fungsi untuk melakukan penggabungan antara dua list

# %%
obj_list = [2, 4, 5, 6]
obj_penambah = [1, 2, 3]

#yourcode
def penggabungan(inp_list1, inp_list2):
  gabung = inp_list1 + inp_list2
  return gabung

penggabungan(obj_list, obj_penambah)
# Out:
# [2, 4, 5, 6, 1, 2, 3]

# %% [markdown]
# Expected Output:
#
# [2, 4, 5, 6, 1, 2, 3]

# %% [markdown]
# <h2>Soal 7: Exercise 1</h2>

# %% [markdown]
# **buat** fungsi untuk menghitung selisih kuadrat (x kuadrat - y kuadrat) dari dua bilangan

# %%
def get_selisih_kuadrat(x,y):
    kuadrat = (x ** 2) - (y ** 2)
    return kuadrat

print(get_selisih_kuadrat(7,2))
print(get_selisih_kuadrat(10,8))
print(get_selisih_kuadrat(-5,6))
# Out:
# 45
# 36
# -11

# %% [markdown]
# <h2>Soal 8: Exercise 2</h2>

# %% [markdown]
# buat function untuk menentukan apakah suatu bilangan ganjil atau genap

# %%
def get_ganjil_genap(inp):
  if inp % 2 == 0:
    hasil = 'Nomor anda Genap'
  else:
    hasil = 'Nomor anda Ganjil'
  
  return hasil

print(get_ganjil_genap(3))
print(get_ganjil_genap(12))
# Out:
# Nomor anda Ganjil
# Nomor anda Genap

# %% [markdown]
# <h2>Soal 9: Exercise 3</h2>

# %% [markdown]
# buat fungsi kalkulator scientific dengan parameter berupa perintah dan angkanya, dan mengembalikan nilai tersebut sebagai float. perlu diperhatikan bahwa string perintah bisa dimasukkan tanpa memperdulikan huruf besar dan kecilnya. string perintah dan operasi matematika yang dilakukan dapat dilihat di bawah ini

# %% [markdown]
# akardua:	Mendapatkan akar pangkat dua dari bilangan

# %% [markdown]
# log10	Mendapatkan logaritma basis 10 dari bilangan

# %% [markdown]
# pangkattiga	Mendapatkan pangkat tiga dari bilangan

# %% [markdown]
# log2	Mendapatkan logaritma basis 2 dari

# %%
import math
akar_pangkat = ['akardua', 'AkarDua', 'akarDua', 'Akardua', 'AKARDUA', 'akar_dua', 'Akar_Dua', 'Akar_dua', 'akar_Dua', 'AKAR_DUA']
nama_log2 = ['log2', 'Log2', 'LOG2', 'LoG2']
pangkat_tiga = ['PangkatTiga', 'PANGKATTIGA', 'Pangkattiga', 'pangkatTiga', 'pangkattiga', 'PANGKAT_TIGA', 'Pangkat_Tiga', 'Pangkat_tiga', 'pangkat_Tiga', 'pangkat_tiga']

def calculator(perintah, angka):
  if perintah in akar_pangkat:
    #hasil = angka ** (1/2)
    hasil = math.sqrt(angka)
  elif perintah in nama_log2:
    hasil = math.log2(angka)
  elif perintah in pangkat_tiga:
    #hasil = angka ** 3
    hasil = math.pow(angka, 3)

  return hasil

print(calculator('Akardua',225))
print(calculator('log2',64))
print(calculator('pangkatTiga',7))
print(calculator('akarDua',729))
print(calculator('akar_Dua',100))
# Out:
# 15.0
# 6.0
# 343.0
# 27.0
# 10.0

# %% [markdown]
# **Hint:** untuk mendapatkan fungsi math yang lain, bisa dilihat di halaman berikut https://docs.python.org/3/library/math.html
