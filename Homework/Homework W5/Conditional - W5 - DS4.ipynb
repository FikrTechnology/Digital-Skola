# %% [markdown]
# ## Sequential

# %%
a = 20
b = 10
c = a - b

print('a - b = ', c)
# Out:
# a - b =  10

# %% [markdown]
# ## Conditional

# %%
a = 3
b = 5

if a > b:
  print('a is bigger than b')
else:
  print('a is smaller than b')
# Out:
# a is smaller than b

# %%
rain = True

if rain == True:
  print('grab umbrella')
  print('put on boots')
else:
  print('wear glasses')
  print('put on sneakers')
print('go to work')
# Out:
# grab umbrella
# put on boots
# go to work

# %%
IBM = 10000
microsoft = 5000

if IBM > 5000 and microsoft < 10000:
  print('confused')
else:
  print('choose one')
# Out:
# confused

# %%
apple = 'buah'

if apple == 'buah':
  print('buah')
else:
  print('Gadget')
# Out:
# buah

# %%
a = 1
b = 2
c = 3

if c > a and a + b == c:
  print(a + b + c)
else:
  print('kondisi tidak memenuhi')
# Out:
# 6

# %%
x = 1

if x % 2 == 0:
  print('x is even number')
else:
  print('x is odd number')
# Out:
# x is odd number

# %%
a = 3
b = 5

if a > b:
  print('a is bigger than b')
elif a < b:
  print('a is smaller than b')
else:
  print('i and jhas same value')
# Out:
# a is smaller than b

# %%
# Nested If

x = 15

if x > 10:
  print('above ten, ')
  if x > 20:
    print('and also above 20!')
  else:
    print('but not above 20')
else:
  print('under ten')
# Out:
# above ten,
# but not above 20

# %%
x = 5

if x < 0:
  print('Positive Number')
elif x > 0:
  print('Positif Number')
else:
  print('Zero')
# Out:
# Positif Number

# %%
usia = int(input())

if usia <= 5:
  print('balita')
elif usia <= 13:
  print('anak-anak')
elif usia <= 18:
  print('remaja')
elif usia <= 65:
  print('dewasa')
else:
  print('lanjut usia')
# Out:
# 21
# dewasa

# %%
kelipatan = int(input('masukkan angka: '))

if kelipatan % 7 == 0:
  print('kelipatan 7')
else:
  print('bukan kelipatan 7')
# Out:
# masukkan angka: 99
# bukan kelipatan 7

# %%
user = input('masukkan user: ')

try:
# Out:
# masukkan user: 100
# input valid
