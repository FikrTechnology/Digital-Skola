# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('weatherAUS.csv')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
print(df.info())
print('=' * 50)
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB
# None
# ==================================================
# (145460, 23)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
df.describe(include=[object])
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2013-08-25  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %% [markdown]
# ## Checking Missing Value

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent1 = df.isnull().sum() / df.isnull().count() * 100
percent2 = percent1.sort_values(ascending=False)
missing_data = pd.concat([total, percent2], axis=1, keys=['Total', 'Percentage Null Value %'])
missing_data
# Out:
#                Total  Percentage Null Value %
# Sunshine       69835                48.009762
# Evaporation    62790                43.166506
# Cloud3pm       59358                40.807095
# Cloud9am       55888                38.421559
# Pressure9am    15065                10.356799
# Pressure3pm    15028                10.331363
# WindDir9am     10566                 7.263853
# WindGustDir    10326                 7.098859
# WindGustSpeed  10263                 7.055548
# Humidity3pm     4507                 3.098446
# WindDir3pm      4228                 2.906641
# Temp3pm         3609                 2.481094
# RainTomorrow    3267                 2.245978
# RainToday       3261                 2.241853
# Rainfall        3261                 2.241853
# WindSpeed3pm    3062                 2.105046
# Humidity9am     2654                 1.824557
# WindSpeed9am    1767                 1.214767
# Temp9am         1767                 1.214767
# MinTemp         1485                 1.020899
# MaxTemp         1261                 0.866905
# Location           0                 0.000000
# Date               0                 0.000000

# %% [markdown]
# ## Visualisasi Distribusi Data

# %%
# Mendefinisikan variabel berdasarkan tipe data
df_num = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
df_cat = ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
# Visualisasi Korelasi antar kolom
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# curah hujan di berbagai wilayah di Australia
plt.figure(figsize=(20,10))
df.groupby('Location')['Rainfall'].mean().sort_values().plot(kind='barh')
plt.show()

# %%
# Visualisasi hist df_num
df.hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'MinTemp'}>,
#         <AxesSubplot:title={'center':'MaxTemp'}>,
#         <AxesSubplot:title={'center':'Rainfall'}>,
#         <AxesSubplot:title={'center':'Evaporation'}>],
#        [<AxesSubplot:title={'center':'Sunshine'}>,
#         <AxesSubplot:title={'center':'WindGustSpeed'}>,
#         <AxesSubplot:title={'center':'WindSpeed9am'}>,
#         <AxesSubplot:title={'center':'WindSpeed3pm'}>],
#        [<AxesSubplot:title={'center':'Humidity9am'}>,
#         <AxesSubplot:title={'center':'Humidity3pm'}>,
#         <AxesSubplot:title={'center':'Pressure9am'}>,
#         <AxesSubplot:title={'center':'Pressure3pm'}>],
#        [<AxesSubplot:title={'center':'Cloud9am'}>,
#         <AxesSubplot:title={'center':'Cloud3pm'}>,
#         <AxesSubplot:title={'center':'Temp9am'}>,
#         <AxesSubplot:title={'center':'Temp3pm'}>]], dtype=object)

# %%
# Visualisasi hist df_cat
fig, ax = plt.subplots(3, 3, figsize=(15, 15))

for cat, ax in zip(df_cat, ax.flatten()):
    sns.countplot(cat, data=df, ax=ax)
# Out:
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Checking Outliers
plt.figure(figsize=(20,10))
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
import datetime

df_rain = df[['Date', 'Rainfall']]
df_rain['Year'] = df_rain['Date'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y'))
df_rain['Month'] = df_rain['Date'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y-%m'))
# Out:
# <ipython-input-15-3c8c94ded33c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Year'] = df_rain['Date'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y'))
# <ipython-input-15-3c8c94ded33c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rain['Month'] = df_rain['Date'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y-%m'))

# %%
# grafik rata" curah hujan selama 10 th.
df_rain.groupby('Year')['Rainfall'].mean().plot()
plt.show()

# %%
# grafik rata" curah hujan perbulan selama 10 th
df_rain.groupby('Month')['Rainfall'].mean().plot()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Handling Missing Value

# %%
# Drop kolom dengan Missing Value di atas 35%
df = df.drop(['Evaporation','Sunshine','Cloud9am','Cloud3pm'], axis = 1)

# %%
# Membuat variabel sesuai dengan tipe data
df_cat = df[['WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow','Date','Location']]
df_num = df.drop(['WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow','Date','Location'], axis=1)

# %%
# Looping Handling missing value df_cat

for col in df_cat.columns.values:
    if df[col].isnull().sum() == 0:
        continue
    df_cat[col] = df.groupby('Location')[col].apply(lambda x: x.fillna(x.mode().max()))
# Out:
# <ipython-input-20-d70d5c7b9a24>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = df.groupby('Location')[col].apply(lambda x: x.fillna(x.mode().max()))

# %%
df_cat.isnull().sum()
# Out:
# WindGustDir     6079
# WindDir9am         0
# WindDir3pm         0
# RainToday          0
# RainTomorrow       0
# Date               0
# Location           0
# dtype: int64

# %%
# Jika masih ada null handling missing value secara manual
df_cat['WindGustDir'] = df['WindGustDir'].fillna(df['WindGustDir'].mode().max())
# Out:
# <ipython-input-22-d0a0a3835928>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['WindGustDir'] = df['WindGustDir'].fillna(df['WindGustDir'].mode().max())

# %%
df_cat.isnull().sum()
# Out:
# WindGustDir     0
# WindDir9am      0
# WindDir3pm      0
# RainToday       0
# RainTomorrow    0
# Date            0
# Location        0
# dtype: int64

# %%
# Looping Handling Missing Value df_num

for col in df_num.columns.values:
    if df[col].isnull().sum() == 0:
        continue
    df_num[col] = df.groupby('Location')[col].apply(lambda x: x.fillna(x.mean()))

# %%
df_num.isnull().sum()
# Out:
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# WindGustSpeed     6079
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am      12119
# Pressure3pm      12119
# Temp9am              0
# Temp3pm              0
# dtype: int64

# %%
# Jika masih ada Null handling missing value secara manual
df_num['WindGustSpeed'] = df_num['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())
df_num['Pressure9am'] = df_num['Pressure9am'].fillna(df['Pressure9am'].mean())
df_num['Pressure3pm'] = df_num['Pressure3pm'].fillna(df['Pressure3pm'].mean())

# %%
df_num.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# dtype: int64

# %%
# me Replace kolom Rain Today dan Rain Tomorrow menjadi numerik 0 dan 1
d = {'Yes':1, 'No':0}
df_cat['RainTomorrow'] = df_cat['RainTomorrow'].map(d)
df_cat['RainToday'] = df_cat['RainToday'].map(d)
# Out:
# <ipython-input-28-9b32c15fedf3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['RainTomorrow'] = df_cat['RainTomorrow'].map(d)
# <ipython-input-28-9b32c15fedf3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['RainToday'] = df_cat['RainToday'].map(d)

# %%
df_cat2 = df_cat[['WindGustDir','WindDir9am','WindDir3pm','Location']]

# Me replace tipe data kategori menjadi value counts
df_cat2['WindGustDir'] = df_cat2['WindGustDir'].map(df_cat2['WindGustDir'].value_counts())
df_cat2['WindDir9am'] = df_cat2['WindDir9am'].map(df_cat2['WindDir9am'].value_counts())
df_cat2['WindDir3pm'] = df_cat2['WindDir3pm'].map(df_cat2['WindDir3pm'].value_counts())
df_cat2['Location'] = df_cat2['Location'].map(df_cat2['Location'].value_counts())
# Out:
# <ipython-input-29-a978a3fc5a85>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat2['WindGustDir'] = df_cat2['WindGustDir'].map(df_cat2['WindGustDir'].value_counts())
# <ipython-input-29-a978a3fc5a85>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat2['WindDir9am'] = df_cat2['WindDir9am'].map(df_cat2['WindDir9am'].value_counts())
# <ipython-input-29-a978a3fc5a85>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat2['WindDir3pm'] = df_cat2['WindDir3pm'].map(df_cat2['WindDir3pm'].value_counts())
# <ipython-input-29-a978a3fc5a85>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat2['Location'] = df_cat2['Location'].map(df_cat2['Location'].value_counts())

# %%
df_new = pd.merge(df_num, df_cat2, left_index=True, right_index=True)

# %%
df_new
# Out:
#         MinTemp    MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0          13.4  22.900000       0.6      44.000000          20.0
# 1           7.4  25.100000       0.0      44.000000           4.0
# 2          12.9  25.700000       0.0      46.000000          19.0
# 3           9.2  28.000000       0.0      24.000000          11.0
# 4          17.5  32.300000       1.0      41.000000           7.0
# ...         ...        ...       ...            ...           ...
# 145455      2.8  23.400000       0.0      31.000000          13.0
# 145456      3.6  25.300000       0.0      22.000000          13.0
# 145457      5.4  26.900000       0.0      37.000000           9.0
# 145458      7.8  27.000000       0.0      28.000000          13.0
# 145459     14.9  30.383195       0.0      41.268373          17.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               24.0         71.0         22.0       1007.7       1007.1
# 1               22.0         44.0         25.0       1010.6       1007.8
# 2               26.0         38.0         30.0       1007.6       1008.7
# 3                9.0         45.0         16.0       1017.6       1012.8
# 4               20.0         82.0         33.0       1010.8       1006.0
# ...              ...          ...          ...          ...          ...
# 145455          11.0         51.0         24.0       1024.6       1020.3
# 145456           9.0         56.0         21.0       1023.5       1019.1
# 145457           9.0         53.0         24.0       1021.0       1016.8
# 145458           7.0         51.0         24.0       1019.4       1016.5
# 145459          17.0         62.0         36.0       1020.2       1017.9
#
#         Temp9am  Temp3pm  WindGustDir  WindDir9am  WindDir3pm  Location
# 0          16.9     21.8        20241        8847        8877      3040
# 1          17.2     24.3         8252        9022        9584      3040
# 2          21.0     23.2         9069        8847        9584      3040
# 3          18.1     26.5         7133       10282        8554      3040
# 4          17.8     29.7        20241        8067        8885      3040
# ...         ...      ...          ...         ...         ...       ...
# 145455     10.1     22.4         9181       10282        7892      1578
# 145456     10.9     24.5         6620       10282        8951      1578
# 145457     12.5     26.1         9313       10282        8877      1578
# 145458     15.1     26.0         9418        9464        8951      1578
# 145459     15.0     20.9        20241        7860        9310      1578
#
# [145460 rows x 16 columns]

# %% [markdown]
# ## Standarisasi

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_new)
df_scaler = pd.DataFrame(scaler.fit_transform(df_new), columns=df_new.columns)

# %%
df_x = pd.merge(df_scaler, df_cat['RainToday'], left_index=True, right_index=True)

# %%
df_x.hist(bins=50, figsize=(20, 10))
plt.show()

# %%
df_x
# Out:
#          MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0       0.189479 -0.043902 -0.210380       0.299901      0.673183
# 1      -0.751913  0.266079 -0.281947       0.299901     -1.129806
# 2       0.111029  0.350619 -0.281947       0.452211      0.560496
# 3      -0.469496  0.674691 -0.281947      -1.223205     -0.340998
# 4       0.832763  1.280564 -0.162669       0.071435     -0.791746
# ...          ...       ...       ...            ...           ...
# 145455 -1.473647  0.026548 -0.281947      -0.690118     -0.115625
# 145456 -1.348128  0.294259 -0.281947      -1.375515     -0.115625
# 145457 -1.065711  0.519700 -0.281947      -0.233186     -0.566372
# 145458 -0.689154  0.533790 -0.281947      -0.918584     -0.115625
# 145459  0.424827  1.010485 -0.281947       0.091873      0.335123
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0           0.616456     0.108840    -1.442551    -1.476793    -1.222913
# 1           0.387759    -1.320713    -1.296626    -1.045963    -1.117903
# 2           0.845154    -1.638391    -1.053417    -1.491649    -0.982890
# 3          -1.098776    -1.267767    -1.734402    -0.006030    -0.367833
# 4           0.159061     0.691250    -0.907491    -1.016251    -1.387928
# ...              ...          ...          ...          ...          ...
# 145455     -0.870078    -0.950088    -1.345268     1.033904     0.757273
# 145456     -1.098776    -0.685356    -1.491193     0.870485     0.577256
# 145457     -1.098776    -0.844195    -1.345268     0.499081     0.232223
# 145458     -1.327473    -0.950088    -1.345268     0.261382     0.187219
# 145459     -0.183985    -0.367678    -0.761566     0.380231     0.397239
#
#         WindGustDir  WindDir9am  WindDir3pm  Location  RainToday
# 0          2.434305   -0.308741   -0.301522  0.093743          0
# 1         -0.443402   -0.192239    0.271735  0.093743          0
# 2         -0.247298   -0.308741    0.271735  0.093743          0
# 3         -0.711994    0.646571   -0.563421  0.093743          0
# 4          2.434305   -0.828004   -0.295036  0.093743          0
# ...             ...         ...         ...       ...        ...
# 145455    -0.220415    0.646571   -1.100190 -5.132120          0
# 145456    -0.835129    0.646571   -0.241521 -5.132120          0
# 145457    -0.188731    0.646571   -0.301522 -5.132120          0
# 145458    -0.163528    0.102010   -0.241521 -5.132120          0
# 145459     2.434305   -0.965809    0.049567 -5.132120          0
#
# [145460 rows x 15 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df_x.drop('Temp9am', axis=1, inplace=True)
df_x.drop('Temp3pm', axis=1, inplace=True)

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_x, df_cat['RainTomorrow'], test_size=0.2, random_state=50)

# %%
# Oversampled

from imblearn.over_sampling import SMOTE
from collections import Counter

sm = SMOTE(random_state = 37)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

print('Sebelum {}'.format(Counter(y_train)))
print('Sesudah {}'.format(Counter(y_train_res)))
# Out:
# Sebelum Counter({0: 90784, 1: 25584})
# Sesudah Counter({1: 90784, 0: 90784})

# %% [markdown]
# # Modelling

# %%
# XGBoost
from sklearn import datasets, linear_model, metrics
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from xgboost import XGBClassifier

model = XGBClassifier(max_depth=10, random_state=37)
model.fit(X_train_res, y_train_res)
model.score(X_train_res, y_train_res)

y_pred = model.predict(X_test)

print('Confusion Matrix \n {}'.format(confusion_matrix(y_test, y_pred)))
print('Accuracy Score {:.2f}'.format(accuracy_score(y_test, y_pred) * 100))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-39-b273d28dc222> in <module>
#       2 from sklearn import datasets, linear_model, metrics
#       3 from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
# ----> 4 from xgboost import XGBClassifier
#       5
#       6 model = XGBClassifier(max_depth=10, random_state=37)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/__init__.py in <module>
#       7 import os
#       8
# ----> 9 from .core import DMatrix, DeviceQuantileDMatrix, Booster
#      10 from .training import train, cv
#      11 from . import rabit  # noqa
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py in <module>
#     193
#     194 # load the XGBoost library globally
# --> 195 _LIB = _load_lib()
#     196
#     197
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py in _load_lib()
#     176     if not lib_success:
#     177         libname = os.path.basename(lib_paths[0])
# --> 178         raise XGBoostError(
#     179             'XGBoost Library ({}) could not be loaded.\n'.format(libname) +
#     180             'Likely causes:\n' +
#
# XGBoostError: XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/macintosh/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_test, y_test)

y_knn_pred = knn.predict(X_train_res)

knn.score(X_test, y_test)

# %%
print('Confusion Matrix \n {}'.format(confusion_matrix(y_train_res, y_knn_pred)))
print('Accuracy Score {:.2f}'.format(accuracy_score(y_train_res, y_knn_pred) * 100))
print(classification_report(y_train_res, y_knn_pred))
