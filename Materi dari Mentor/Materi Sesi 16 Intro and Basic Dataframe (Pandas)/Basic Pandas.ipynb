# %% [markdown]
# # Basic Pandas
#
# ## Import Library

# %%
import pandas as pd, numpy as np

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create Dataframe
#
# ### Create from List

# %%
list1 = [1,2,3]
list2 = ['Agil', 'Budi', 'Aryo']
column_names = ['number', 'name']
df = pd.DataFrame(list(zip(list1, list2)), columns=column_names)
df
# Out:
#    number  name
# 0       1  Agil
# 1       2  Budi
# 2       3  Aryo

# %% [markdown]
# ### Create from Array

# %%
no_induk = [100, 102, 103]
nama = ['A', 'B', 'C']
nilai = [9.4, 7.6, 10.0]
siswa = np.array([no_induk, nama, nilai])
df2 = pd.DataFrame(siswa)
df2
# Out:
#      0    1     2
# 0  100  102   103
# 1    A    B     C
# 2  9.4  7.6  10.0

# %% [markdown]
# ### Create from Series

# %%
no_induk = pd.Series(no_induk)
nama = pd.Series(nama)
nilai = pd.Series(nilai)
df3 = pd.DataFrame(no_induk, columns=['no induk'])
df3['nama'] = nama
df3['nilai'] = nilai
df3
# Out:
#    no induk nama  nilai
# 0       100    A    9.4
# 1       102    B    7.6
# 2       103    C   10.0

# %% [markdown]
# ### Create from tuple

# %%
numbers = tuple([1,2,3,4])
alphabets = tuple(['A', 'B', 'C', 'D'])
df4 = pd.DataFrame([numbers, alphabets]).T
df4
# Out:
#    0  1
# 0  1  A
# 1  2  B
# 2  3  C
# 3  4  D

# %% [markdown]
# ### Create from Dictionary

# %%
kota = ['Jakarta', 'Medan', 'Banyuwangi']
jml_pdd = [15000000, 7000000, 1500000]
dict_kota = {
    'kota': kota,
    'jumlah penduduk': jml_pdd
}
df5 = pd.DataFrame(dict_kota)
df5
# Out:
#          kota  jumlah penduduk
# 0     Jakarta         15000000
# 1       Medan          7000000
# 2  Banyuwangi          1500000

# %% [markdown]
# ## Load Dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/MyDrive/DigitalSkola/Dataset/sample.csv'
dataset = pd.read_csv(path, delimiter=',')
dataset
# Out:
#              order_id  sales  profit  ...     ship_mode        lon        lat
# 0     AZ-2011-2320734     13       2  ...       Economy   2.333764  48.911856
# 1     AZ-2014-1914770     92      42  ...      Priority  -0.168749  50.827932
# 2     BN-2011-5443120    205    -127  ...  Economy Plus  -8.410257  40.203315
# 3     BN-2014-2645644     48     -22  ...      Priority   4.300700  52.070498
# 4     AZ-2012-9764957     75      26  ...       Economy   9.993682  53.551085
# ...               ...    ...     ...  ...           ...        ...        ...
# 1488  AZ-2014-5931184     12       1  ...      Priority   7.447447  46.947974
# 1489  AZ-2011-8034411     54      12  ...       Economy  11.102228  43.877705
# 1490  AZ-2013-8360642     38       6  ...      Priority   2.257289  48.799815
# 1491  AZ-2014-4726682    122      43  ...      Priority  14.036640  48.165420
# 1492  AZ-2014-2406788     32       4  ...  Economy Plus  11.581981  48.135125
#
# [1493 rows x 19 columns]

# %% [markdown]
# ## Data Selection
#
# ### Top/Bottom Rows

# %%
dataset.head()
# Out:
#           order_id  sales  profit  ...     ship_mode       lon        lat
# 0  AZ-2011-2320734     13       2  ...       Economy  2.333764  48.911856
# 1  AZ-2014-1914770     92      42  ...      Priority -0.168749  50.827932
# 2  BN-2011-5443120    205    -127  ...  Economy Plus -8.410257  40.203315
# 3  BN-2014-2645644     48     -22  ...      Priority  4.300700  52.070498
# 4  AZ-2012-9764957     75      26  ...       Economy  9.993682  53.551085
#
# [5 rows x 19 columns]

# %%
dataset.tail()
# Out:
#              order_id  sales  profit  ...     ship_mode        lon        lat
# 1488  AZ-2014-5931184     12       1  ...      Priority   7.447447  46.947974
# 1489  AZ-2011-8034411     54      12  ...       Economy  11.102228  43.877705
# 1490  AZ-2013-8360642     38       6  ...      Priority   2.257289  48.799815
# 1491  AZ-2014-4726682    122      43  ...      Priority  14.036640  48.165420
# 1492  AZ-2014-2406788     32       4  ...  Economy Plus  11.581981  48.135125
#
# [5 rows x 19 columns]

# %% [markdown]
# ### Get Data Dimension

# %%
# Shape of dataframe
print(dataset.shape)
# Out:
# (1493, 19)

# %%
# Size of dataframe
print(dataset.size)
# Out:
# 28367

# %%
print('jumlah baris:', dataset.shape[0], '. jumlah kolom:', dataset.shape[1])
# Out:
# jumlah baris: 1493 . jumlah kolom: 19

# %% [markdown]
# ### Get Column Names

# %%
print(dataset.columns)
# Out:
# Index(['order_id', 'sales', 'profit', 'quantity', 'category', 'sub_category',
#        'Cost', 'Total_Cost', 'Total_profit', 'order_date', 'customer_name',
#        'city', 'country', 'region', 'segment', 'ship_date', 'ship_mode', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Get Specific Column/s

# %%
customer_trx = dataset[['order_id', 'sales', 'customer_name']]

# %%
customer_trx.head()
# Out:
#           order_id  sales   customer_name
# 0  AZ-2011-2320734     13   Charlie Wells
# 1  AZ-2014-1914770     92     Cooper Burn
# 2  BN-2011-5443120    205  Kaitlyn Dorsch
# 3  BN-2014-2645644     48  Jeremy Pilcher
# 4  AZ-2012-9764957     75     Abbie Perry

# %%
dataset[['segment']]
# Out:
#           segment
# 0     Home Office
# 1        Consumer
# 2       Corporate
# 3       Corporate
# 4        Consumer
# ...           ...
# 1488  Home Office
# 1489  Home Office
# 1490     Consumer
# 1491     Consumer
# 1492     Consumer
#
# [1493 rows x 1 columns]

# %%
# Cara hapus variable di dalam RAM
del df , df2, df3, df4, df5

# %% [markdown]
# ### Get Specific Row/s

# %%
dataset[0:1]
# Out:
#           order_id  sales  profit  ...  ship_mode       lon        lat
# 0  AZ-2011-2320734     13       2  ...    Economy  2.333764  48.911856
#
# [1 rows x 19 columns]

# %%
dataset.iloc[:10]
# Out:
#           order_id  sales  profit  ...     ship_mode        lon        lat
# 0  AZ-2011-2320734     13       2  ...       Economy   2.333764  48.911856
# 1  AZ-2014-1914770     92      42  ...      Priority  -0.168749  50.827932
# 2  BN-2011-5443120    205    -127  ...  Economy Plus  -8.410257  40.203315
# 3  BN-2014-2645644     48     -22  ...      Priority   4.300700  52.070498
# 4  AZ-2012-9764957     75      26  ...       Economy   9.993682  53.551085
# 5  AZ-2013-5719967    304      72  ...       Economy   2.130544  48.825415
# 6  AZ-2012-2193596     34      15  ...       Economy   2.352222  48.856614
# 7  AZ-2013-3174742    107       9  ...       Economy  15.083030  37.507877
# 8  BN-2014-6632260    385     -77  ...       Economy  -2.323702  53.425561
# 9  AZ-2014-4622829    281     129  ...       Economy  12.496365  41.902784
#
# [10 rows x 19 columns]

# %%
dataset.iloc[-10:-7]
# Out:
#              order_id  sales  profit  ...  ship_mode       lon        lat
# 1483  BN-2012-1467003    140      34  ...    Economy  0.078082  43.232951
# 1484  AZ-2012-1979551     69      18  ...    Economy  6.807685  50.999581
# 1485  AZ-2013-8583368    303      33  ...    Economy  2.522163  48.770878
#
# [3 rows x 19 columns]

# %%
dataset.iloc[100:200]
# Out:
#             order_id  sales  profit  ...     ship_mode        lon        lat
# 100  AZ-2012-9553455     30      15  ...       Economy   2.035041  41.345841
# 101  AZ-2014-9580273     94       7  ...      Priority  12.099147  54.092441
# 102  AZ-2014-1490273   1280     299  ...       Economy   7.626135  51.960665
# 103  BN-2013-3350047   1554     730  ...       Economy   2.268510  48.884831
# 104  AZ-2012-9211043     25      11  ...       Economy   6.688373  50.874759
# ..               ...    ...     ...  ...           ...        ...        ...
# 195  AZ-2011-9164512    174     -38  ...  Economy Plus   4.895168  52.370216
# 196  BN-2011-4097137    159     -39  ...       Economy  -9.224547  38.757760
# 197  BN-2011-6545829     19       8  ...       Economy  -3.809980  43.462306
# 198  AZ-2014-6368939     54      12  ...  Economy Plus  11.581981  48.135125
# 199  AZ-2014-2413956     67      26  ...  Economy Plus   3.876716  43.610769
#
# [100 rows x 19 columns]

# %%
dataset.iloc[-200:-100]
# Out:
#              order_id  sales  profit  ...  ship_mode        lon        lat
# 1293  AZ-2011-8060550    123      50  ...   Priority  12.243044  45.666889
# 1294  AZ-2012-6193162    327     116  ...    Economy   6.789995  50.657439
# 1295  AZ-2012-7761604     67     -30  ...    Economy  -1.890401  52.486243
# 1296   BN-2014-323564     47    -114  ...    Economy  -1.470085  53.381129
# 1297  BN-2013-5107486    191    -187  ...    Economy   4.300700  52.070498
# ...               ...    ...     ...  ...        ...        ...        ...
# 1388  AZ-2012-8186221    636     146  ...    Economy  11.581981  48.135125
# 1389   BN-2011-188092    117      40  ...    Economy  10.097677  44.079324
# 1390   AZ-2014-783246    346     108  ...   Priority  -0.879787  47.059407
# 1391  AZ-2012-9269920     13       5  ...    Economy   6.762329  51.434408
# 1392  AZ-2012-5156362     75       1  ...    Economy  13.404954  52.520007
#
# [100 rows x 19 columns]

# %%
dataset.iloc[100:200, :3]
# Out:
#             order_id  sales  profit
# 100  AZ-2012-9553455     30      15
# 101  AZ-2014-9580273     94       7
# 102  AZ-2014-1490273   1280     299
# 103  BN-2013-3350047   1554     730
# 104  AZ-2012-9211043     25      11
# ..               ...    ...     ...
# 195  AZ-2011-9164512    174     -38
# 196  BN-2011-4097137    159     -39
# 197  BN-2011-6545829     19       8
# 198  AZ-2014-6368939     54      12
# 199  AZ-2014-2413956     67      26
#
# [100 rows x 3 columns]

# %%
dataset.loc[100:199, ['segment', 'country', 'Cost']]
# Out:
#          segment      country  Cost
# 100    Corporate        Spain    15
# 101     Consumer      Germany    87
# 102     Consumer      Germany   981
# 103     Consumer       France   824
# 104     Consumer      Germany    14
# ..           ...          ...   ...
# 195     Consumer  Netherlands   212
# 196     Consumer     Portugal   139
# 197     Consumer        Spain    11
# 198  Home Office      Germany    42
# 199    Corporate       France    41
#
# [100 rows x 3 columns]

# %% [markdown]
# # Type Data & Stat Descriptive

# %%
dataset.dtypes
# Out:
# order_id          object
# sales              int64
# profit             int64
# quantity           int64
# category          object
# sub_category      object
# Cost               int64
# Total_Cost         int64
# Total_profit       int64
# order_date        object
# customer_name     object
# city              object
# country           object
# region            object
# segment           object
# ship_date         object
# ship_mode         object
# lon              float64
# lat              float64
# dtype: object

# %%
dataset.describe()
# Out:
#              sales       profit  ...          lon          lat
# count  1493.000000  1493.000000  ...  1493.000000  1493.000000
# mean    306.198259    38.541192  ...     5.235207    48.782571
# std     517.356975   165.200903  ...     6.485921     5.021450
# min       4.000000 -1752.000000  ...    -9.224547    35.889387
# 25%      52.000000     1.000000  ...    -0.127758    45.387638
# 50%     117.000000    15.000000  ...     5.121420    49.258329
# 75%     319.000000    50.000000  ...     9.993682    52.120533
# max    5785.000000  1898.000000  ...    25.037769    60.794533
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Sampling Dataset

# %%
sampled_data = dataset.sample(frac=0.5, random_state=12)
sampled_data.head()
# Out:
#              order_id  sales  profit  ...  ship_mode        lon        lat
# 502   AZ-2011-5463300     21       9  ...    Economy   6.143158  46.204391
# 1180  AZ-2011-6683192     36       8  ...   Priority   8.020959  50.883849
# 1094  AZ-2011-9119536    112      55  ...    Economy  12.315515  45.440847
# 649   AZ-2013-9573927    311    -292  ...   Priority  -8.486316  51.896892
# 767   BN-2012-9976090     73     -51  ...    Economy  -1.890401  52.486243
#
# [5 rows x 19 columns]

# %% [markdown]
# ### Filter Data

# %%
sampled_data.loc[sampled_data['profit'] < 0]
# Out:
#              order_id  sales  profit  ...     ship_mode        lon        lat
# 649   AZ-2013-9573927    311    -292  ...      Priority  -8.486316  51.896892
# 767   BN-2012-9976090     73     -51  ...       Economy  -1.890401  52.486243
# 1040  BN-2013-9926490    400    -256  ...  Economy Plus  12.568337  55.676097
# 1290  BN-2013-2658555    104      -5  ...  Economy Plus  11.581981  48.135125
# 400   BN-2012-5319905     70    -271  ...       Economy  -1.890401  52.486243
# ...               ...    ...     ...  ...           ...        ...        ...
# 1335  BN-2013-3470282     33     -12  ...      Priority   4.300700  52.070498
# 1110  BN-2011-3032749     26     -14  ...     Immediate   9.732010  52.375892
# 818   BN-2011-6162681   2229    -754  ...      Priority  -0.588054  44.802614
# 811   BN-2012-5238794    207    -120  ...       Economy   5.091914  51.560596
# 844   BN-2014-5562074    275    -275  ...       Economy  -8.426507  41.545449
#
# [163 rows x 19 columns]

# %%
sampled_data.loc[(sampled_data['profit'] < 0) & (sampled_data['country'] == 'United Kingdom'),
                 ['country', 'order_id', 'profit']]
# Out:
#              country         order_id  profit
# 767   United Kingdom  BN-2012-9976090     -51
# 400   United Kingdom  BN-2012-5319905    -271
# 442   United Kingdom  BN-2014-6988890      -5
# 450   United Kingdom  AZ-2011-5004051      -4
# 1140  United Kingdom  AZ-2012-9094578    -290
# 1126  United Kingdom  BN-2013-8249195     -36
# 388   United Kingdom  BN-2013-7296416      -9
# 246   United Kingdom  BN-2011-5036253     -44
# 190   United Kingdom  BN-2013-8249195    -129
# 1296  United Kingdom   BN-2014-323564    -114
# 302   United Kingdom  BN-2013-4388015     -18
# 1163  United Kingdom  BN-2014-3536767      -3
# 322   United Kingdom  AZ-2014-9560415      -1
# 154   United Kingdom  AZ-2012-5629716    -122
# 424   United Kingdom  AZ-2012-7448408      -5

# %%
# Dari kategori Technology, transaksi mana aja yang Cost nya lebih dari 500?
sampled_data.loc[(sampled_data['Cost'] > 500) & (sampled_data['category'] == 'Technology')]
# Out:
#              order_id  sales  profit  ...     ship_mode        lon        lat
# 252   AZ-2012-5770966   1081     102  ...  Economy Plus   5.928000  43.124228
# 1178  AZ-2013-5974172    592    -643  ...  Economy Plus   1.444209  43.604652
# 583   AZ-2013-2994768   1638     730  ...       Economy   2.130122  48.801408
# 177   AZ-2014-5157015   3201    1216  ...       Economy  -1.383801  54.906869
# 1046  AZ-2013-3983168    613    -343  ...      Priority   5.121420  52.090737
# 474    AZ-2012-925819   3442      38  ...  Economy Plus  -0.127758  51.507351
# 39    AZ-2012-5139893   2123     125  ...       Economy   3.876716  43.610769
# 1471  AZ-2013-1146430   1208     274  ...       Economy  -0.127758  51.507351
# 1208  AZ-2014-7578563    918      22  ...  Economy Plus   5.369780  43.296482
# 111   AZ-2012-3590299    815     -91  ...      Priority  -4.107888  38.688446
# 461   AZ-2014-9634517   1543     370  ...       Economy  14.292825  40.907598
# ...

# %% [markdown]
# # Save as CSV

# %%
df = sampled_data.loc[(sampled_data['Cost'] > 500) & (sampled_data['category'] == 'Technology')]
save_path = '/content/gdrive/MyDrive/DigitalSkola/Dataset/technology cost more than 500.csv'
df.to_csv(save_path, index=False)
